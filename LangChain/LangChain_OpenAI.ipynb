# %% [markdown]
# ## Step 1: Set Your OpenAI API Key

# %%
import os
# Replace with your real OpenAI API key
os.environ['OPEN_API_KEY'] = 'your_api_key'

# %% [markdown]
# ## Step 2: Build Your First Chain

# %%
from langchain_openai import ChatOpenAI  
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain


# Load the model
llm = ChatOpenAI(model_name="gpt-3.5-turbo",
                 temperature=0,
                 api_key='you_api_key'
                )

# Define a prompt template with a variable
prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners."
)

#create an LLM chain
chain= LLMChain(llm=llm, prompt=prompt)

#Run the chain with an input
response = chain.run('reinforement learning')
print("🧠 Output:\n", response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[9], line 22
#      19 chain= LLMChain(llm=llm, prompt=prompt)
#      21 #Run the chain with an input
# ---> 22 response = chain.run('reinforement learning')
#      23 print("🧠 Output:\n", response)
#
# File /opt/anaconda3/envs/ai_env/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File /opt/anaconda3/envs/ai_env/lib/python3.11/site-packages/langchain/chains/base.py:603, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     601     if len(args) != 1:
#     602         raise ValueError("`run` supports only one positional argument.")
# ...

# %% [markdown]
# What you just built->
#
# PromptTemplate:
# Defines the input and structure of your prompt.
#
# ChatOpenAI:
# Wraps the model (could also be Cohere, HuggingFace, etc.)
#
# LLMChain:
# Glues model + prompt together into a callable pipeline
#
# chain.run(...):
# Sends input → gets LLM output
